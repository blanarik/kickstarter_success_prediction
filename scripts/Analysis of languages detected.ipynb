# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data_out/cv.csv')

# %%
df[['text', 'lang_1', 'conf_1', 'lang_2', 'conf_2']]
# Out:
#                                                    text lang_1    conf_1  \
# 0     You'll need an HTML5 capable browser to see th...     en  1.000000
# 1     Ostrich can save the world?In today's world we...     en  1.000000
# 2     A MASSIVE THANK YOU TO ALL OUR BACKERS AND EVE...     en  1.000000
# 3     UNDER THE RADAR IS... a community that celebra...     en  1.000000
# 4     We are launching a new pork product called Big...     en  1.000000
# 5     Hello there! I'm Amrit Brar, a Toronto-based i...     en  1.000000
# 6     There are two pins availableOriginal Pin Love ...     en  1.000000
# 7     As a photographer, I have travelled to 16 coun...     en  1.000000
# 8     I am looking to raise $4000 to use as a down p...     en  1.000000
# 9     Hi, First I would like to say thank you for ta...     en  1.000000
# 10    I'd love to have a little free library to buil...     en  1.000000
# 11    ? $40,000 Stretch Goal Achieved! You made it R...     en  1.000000
# 12    At the age of 15 I started working for an Ital...     en  1.000000
# 13    Off the Block for the third consecutive year i...     en  1.000000
# 14    In which Huckelberry sets out to the American ...     en  1.000000
# 15    Hello everyone,My name is Keven Diamond, a you...     en  1.000000
# 16    Don?t you want to find the best pub for your n...     en  1.000000
# 17    I've been painting with watercolours for a few...     en  1.000000
# 18    The Sixfab Raspberry Pi IoT Shield Family was ...     en  1.000000
# 19    This is a story my son and i came up with last...     en  1.000000
# 20    WHAT?PeruseLab is a cloud-based chemical infor...     en  1.000000
# 21    This crowdfunding project, Blues for the block...     en  1.000000
# 22    In the beginning God created the Heavens and E...     en  1.000000
# 23    Apr?s des centaines de spectacles partout au Q...     fr  1.000000
# 24    Mountain Movers Inc. is producing a Breast Can...     en  1.000000
# 25    Hello all,We're a group of the three students ...     en  1.000000
# 26    KC Presentsor King CAF Presents will be a down...     en  1.000000
# 27    A few years ago, we created a game with an epi...     en  1.000000
# 28    Origins Over the past few years I have been wh...     en  1.000000
# 29    If you missed this project, check us out at ht...     en  1.000000
# ...                                                 ...    ...       ...
# 6070  Hello there, my name is Mia, nice to meet you!...     en  1.000000
# 6071  Retroball is a build-it-yourself kit which fol...     en  1.000000
# 6072                                                NaN    und  1.000000
# 6073  Hi, and thank you for watching my video. I hop...     en  1.000000
# 6074  A home for the pet parent community . . . The ...     en  1.000000
# 6075  The Back StorySpice Bros when it all beganWhen...     en  1.000000
# 6076  Time Line ProjectEnglish version:The Bitcoin e...     en  0.982331
# 6077  The Cass Clutch's simple and flexible design a...     en  1.000000
# 6078  Timeless American ~ A Selection Of Pre-1916 Mo...     en  1.000000
# 6079  The Hispanic community is quickly rising and w...     en  1.000000
# 6080  ***Hear a brief clip of my song, Banjo Picker ...     en  1.000000
# 6081  I discovered Tim's work in Lech and was impres...     en  1.000000
# 6082  Origin of the dweebsThis comic has been in the...     en  1.000000
# 6083  Wolf at the Door  Hello, hello, hello!My name ...     en  1.000000
# 6084  Teaser of the new album:Mini album 'Blue Econo...     en  1.000000
# 6085  First and Foremost, Thank you for visiting and...     en  1.000000
# 6086  Capstone Coverage is a brand new podcast that ...     en  1.000000
# 6087  After filming live music for the past three ye...     en  1.000000
# 6088  The Acro-Cats need a new mobile foster and kit...     en  1.000000
# 6089  The Kickstarter is finished, but you can still...     en  1.000000
# 6090  I think the special incentive for backing this...     en  1.000000
# 6091  El Lago de los Cisnes, Compa?ía Nacional de Da...     es  0.985336
# 6092   WOW Multi-Lens Case for the for iPhone7 Sleek...     en  1.000000
# 6093  This project is starting from ground zero. We ...     en  1.000000
# 6094  Dear kickstarter Funding visitors,Hi, I am Don...     en  1.000000
# 6095  Dear Friends, This little video captures my st...     en  1.000000
# 6096  The MYO Fitness non-profit organization consis...     en  1.000000
# 6097   The ThermoPen StoryThe ThermoPen offers much ...     en  1.000000
# 6098  Presenting SHERIFF WRIGHT, the debut comic boo...     en  1.000000
# 6099  Allison Shaw is raising funds to print a compl...     en  1.000000
#
#      lang_2    conf_2
# 0        en  0.970497
# 1        en  1.000000
# 2        en  1.000000
# 3        en  1.000000
# 4        en  1.000000
# 5        en  1.000000
# 6        en  1.000000
# 7        en  0.741775
# 8        en  1.000000
# 9        en  1.000000
# 10       en  1.000000
# 11       en  1.000000
# 12       en  1.000000
# 13       en  1.000000
# 14       en  1.000000
# 15       en  1.000000
# 16       en  1.000000
# 17       fr  1.000000
# 18       en  1.000000
# 19       en  1.000000
# 20       en  1.000000
# 21       en  1.000000
# 22       en  1.000000
# 23       fr  1.000000
# 24       en  1.000000
# 25       en  1.000000
# 26       en  1.000000
# 27       en  1.000000
# 28       en  1.000000
# 29       en  1.000000
# ...     ...       ...
# 6070     en  1.000000
# 6071     en  1.000000
# 6072    und  1.000000
# 6073     en  1.000000
# 6074     en  1.000000
# 6075     en  1.000000
# 6076     es  1.000000
# 6077     en  0.987441
# 6078     en  1.000000
# 6079     en  1.000000
# 6080     en  1.000000
# 6081     en  1.000000
# 6082     en  1.000000
# 6083     en  1.000000
# 6084     en  1.000000
# 6085     en  1.000000
# 6086     en  1.000000
# 6087     en  0.950068
# 6088     en  1.000000
# 6089     en  0.766226
# 6090     en  1.000000
# 6091     es  0.970791
# 6092     en  1.000000
# 6093     en  1.000000
# 6094     en  1.000000
# 6095     en  1.000000
# 6096     en  1.000000
# 6097     en  1.000000
# 6098     en  1.000000
# 6099     en  1.000000
#
# [6100 rows x 5 columns]

# %%
df['lang_1'].value_counts()
# Out:
# en     5756
# es      106
# fr       80
# de       65
# und      37
# sv       25
# it       12
# nl        6
# no        6
# da        3
# id        2
# pt        1
# hu        1
# Name: lang_1, dtype: int64

# %%
pd.crosstab(df['lang_1'], df['class'])
# Out:
# class      1    2     3     4
# lang_1
# da         0    1     1     1
# de        47    7     9     2
# en      2398  743  1290  1325
# es        64    8    24    10
# fr        34   11    18    17
# hu         1    0     0     0
# id         1    0     1     0
# it         7    1     0     4
# nl         3    0     3     0
# no         1    3     1     1
# pt         1    0     0     0
# sv        12    2     9     2
# und       12    8     5    12

# %%
df['lang_2'].value_counts()
# Out:
# en       5697
# es        105
# fr         80
# de         69
# und        60
# it         21
# sv         18
# da          7
# nl          6
# pt          4
# no          4
# sk          3
# hr          3
# ca          3
# co          2
# gl          2
# hu          2
# tr          1
# so          1
# la          1
# uz          1
# ja          1
# mg          1
# id          1
# lt          1
# hi          1
# ms          1
# sq          1
# eo          1
# zh-CN       1
# fi          1
# Name: lang_2, dtype: int64

# %%
pd.crosstab(df['lang_2'], df['class'])
# Out:
# class      1    2     3     4
# lang_2
# ca         0    0     2     1
# co         0    0     1     1
# da         1    3     2     1
# de        47    7     7     8
# en      2385  733  1271  1308
# eo         0    0     0     1
# es        63   10    23     9
# fi         0    1     0     0
# fr        35   11    20    14
# gl         0    0     2     0
# hi         0    0     1     0
# hr         2    0     1     0
# hu         1    1     0     0
# id         1    0     0     0
# it        11    2     3     5
# ja         0    0     1     0
# la         0    0     0     1
# lt         0    0     0     1
# mg         1    0     0     0
# ms         0    0     0     1
# nl         2    0     2     2
# no         2    1     1     0
# pt         1    0     3     0
# sk         1    1     0     1
# so         0    0     0     1
# sq         0    0     0     1
# sv         8    3     5     2
# tr         1    0     0     0
# und       19   11    16    14
# uz         0    0     0     1
# zh-CN      0    0     0     1

# %%
df[df['lang_2'] == 'zh-CN']['url_name']
# Out:
# 1870    girls-by-luo-yang
# Name: url_name, dtype: object

# %%
df.loc[1870, 'text']
# Out:
# '(c) Luo Yang, Beijing Couple, 2011LUO YANG_GIRLSThis book comprises the most beautiful, disturbing and fascinating images from Luo Yang\'s internationally acclaimed series GIRLS (2007-2017), as seen on BBC, ARTE Journal or Huffington Post. Luo\'s GIRLS belong to a part of contemporary China that is rarely taken note of in the West. Her portraits depict an emerging Chinese subculture that defies imposed expectations and stereotypes: GIRLS are badassed and self-aware with a supreme sense of cool, yet also insecure, vulnerable and torn. Luo photographs the girls around her, attempting to grasp an understanding of their lives as well as her own. Although different, they share the same ambivalent emotions, confusions and concerns. It is in that connection that Luo finds the strength and fragility of her subject. ?By shooting girls I understand their life better and it makes my own world bigger and wider. We might have different values and worldviews, but what we have in common are a fragility and braveness inside of us. We face the world with our sincerity.? (Luo Yang)Borne from this intuitive dialogue with her subjects, Luo?s images are bold and honest, intimate and sensitive at the same time. Her work explores the themes of youth and femininity, while challenging traditional beliefs about women in Chinese society. ABOUT US: LUO YANG & MOLuo Yang, born 1984 in Liaoning Province in China\'s northeast, is a freelance photographer living and working in Beijing & Shanghai. One of the "rising stars of Chinese photography" (New Statesman, 2012), she has had numerous exhibitions in China and participated in major shows in Europe, amongst them Ai Weiwei?s ?FUCK OFF 2? at the Groninger Museum, Netherlands, in 2013. Solo exhibitions in Berlin and Hong Kong have since contributed to her international recognition. In her work, highly staged portraits and carefully constructed poses alternate with a raw, blurred snapshot-aesthetic. She works with film cameras only, deliberately slowing down the creative process and focusing on a particular moment itself rather than on elaborating and refining an image in post-production. MO-Industries is a POP-UP gallery staging cultural exchange between Asia and the West. It is a young venture that started at the end of 2015. Luo Yang and MO have been a team since the beginning of 2016, working closely on internationally showcasing Luo Yang\'s work, while scouting & introducing other exciting artists from China to the West (and vice versa).Please support us in realising this beautiful project!THE BOOK IN FACTS:This compilation, published in a stunning silk-lined hardcover, is scheduled to be released by a renowned publishing house in Vienna in November 2017, reaching international bookstores in Spring 2018. All texts are presented bilingually in English & Mandarin.Hardcover (Printed Silk)Size: 22.5 x 27.5 cmPages: ca. 160Number of Images: ca. 80Essay: ca. 4200 words by Eva MorawietzLanguage: English / MandarinThe Book\'s Cover: Detail of Luo\'s image "Xi Yuan" from 2017"GIRLS"(c) Luo Yang, Pi Pi, 2015 (c) Luo Yang, Jin Jing, 2015 (c) Luo Yang, Jiang Mi, 2011  (c) Luo Yang, Jiang Mi, 2011 (c) Luo Yang, Pi Pi (Highway), 2015  (c) Luo Yang. Ro Ro, 2014 (c) Luo Yang, Mao Er, 2017 (c) Luo Yang, Xu La Di, 2017. The Chinese characters read "Carpe Diem"  INTERNATIONAL PRESS on Luo Yang:BBC NEWS: Photographer Luo Yang Captures China\'s New Generation of GirlsTHE HUFFINGTON POST: Empowered Young Women Star in These Portraits of Chinese GirlhoodARTE JOURNAL: Photographie: Les jeunes femmes de la Chine nouvelleSPIEGEL ONLINE: GIRLS-Ausstellung von Chinesin Luo YangLE JOURNAL INTERNATIONAL: La photographe Chinoise Luo Yang brise la tradition IGNANT: Luo Yang Captures a New Generation of Chinese WomenMIRRORED SOCIETY: Luo Yang. An Exploration of the New Chinese Woman (great bilingual interview with Luo!)STITCH: GIRLS - Luo YangJUXTAPOZ: Luo Yang\'s Photographs of Chinese Women Reveal Duality of Fragility and Inner Strengt ...

# %%
df['conf_1'].plot(kind='hist', logy= True)

# %%
df['conf_2'].plot(kind='hist', logy= True)

# %%
df[df['lang_1'] == df['lang_2']]['lang_1'].value_counts()
# Out:
# en     5605
# es       79
# fr       53
# de       45
# und      35
# sv       14
# it        5
# nl        3
# no        3
# da        2
# id        1
# hu        1
# Name: lang_1, dtype: int64

# %%
df[df['lang_1'] != df['lang_2']][['lang_1', 'lang_2']]
# Out:
#      lang_1 lang_2
# 17       en     fr
# 50       en     es
# 60       en     tr
# 75       en     it
# 77       en     fr
# 109      de     en
# 112      es     en
# 151      es     en
# 157      no     en
# 184      en    und
# 206      de     en
# 209      es     en
# 214      en     it
# 217      en     fr
# 227      en     de
# 264      sv     en
# 284      fr     en
# 291      it     en
# 303      de     en
# 304      en     fr
# 309      fr     en
# 358      en     sk
# 423      en    und
# 427      it     en
# 445      en    und
# 478      fr     en
# 485      en     de
# 591      en    und
# 595      en     es
# 644      en    und
# ...     ...    ...
# 5178     en     es
# 5211     en     de
# 5230     en     pt
# 5378     en     it
# 5384     fr     en
# 5423     fr     en
# 5547     en     de
# 5548     en     de
# 5551     fr     es
# 5576     es     en
# 5589     es     en
# 5634     en    und
# 5694     de     en
# 5730     fr     en
# 5747     en     eo
# 5749     en     fr
# 5816     de     en
# 5833     en     de
# 5834     fr     en
# 5847     es    und
# 5878     en     es
# 5889     es     en
# 5907     en     fr
# 5955     de     en
# 5975     en     es
# 5994     en    und
# 5996     en     de
# 6006     sv     en
# 6030     en     co
# 6076     en     es
#
# [254 rows x 2 columns]

# %%
df[(df['lang_1'] != df['lang_2']) & (df['lang_1'] != 'en') & (df['lang_2'] != 'en')][['lang_1', 'conf_1', 'lang_2', 'conf_2', 'url_name']]
# Out:
#      lang_1    conf_1 lang_2    conf_2  \
# 1050     de  1.000000     hr  0.680948
# 1117     it  0.440260     hr  0.985874
# 1195     es  1.000000     sk  0.495594
# 1818     no  1.000000     da  0.503279
# 2307     sv  0.953062     pt  0.273809
# 3076     es  1.000000     nl  0.412358
# 3535     fr  1.000000     la  1.000000
# 4722     fr  1.000000     es  1.000000
# 4754     pt  0.672452     es  1.000000
# 5551     fr  1.000000     es  0.978034
# 5847     es  1.000000    und  1.000000
#
#                                                url_name
# 1050                                         prijedor92
# 1117  dance-legacy-modern-dance-techniques-new-york-...
# 1195                                       cyberhumanos
# 1818                                kjrlighet-cd-singel
# 2307                                 statement-festival
# 3076                 ari-y-la-cafeteria-de-los-horrores
# 3535   academie-adapt-concevoir-son-habitation-du-futur
# 4722                              josbel-figurita-album
# 4754                    the-audiomultivisual-experience
# 5551                      lengaia-salsa-brava-the-album
# 5847                                disco-pedro-barrero
